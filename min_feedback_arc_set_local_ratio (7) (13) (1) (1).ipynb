# %%
from collections import defaultdict
import torch
import numpy as np

from collections import defaultdict

def read_graph(file_path):
    """
    Reads a weighted directed graph from a file. Each line contains three values:
    start vertex, end vertex, and edge weight.

    Args:
        file_path (str): Path to the file containing the graph.

    Returns:
        edges (list): List of tuples representing directed edges (start, end, weight, edge_id).
    """
    edges = []
    edge_id = 0  # Unique identifier for each edge
    try:
        with open(file_path, 'r') as file:
            for line in file:
                line = line.strip()
                if line:  # Skip empty lines
                    start, end, weight = map(float, line.split())
                    edges.append((int(start), int(end), weight, edge_id))
                    edge_id += 1
    except Exception as e:
        print(f"Error reading graph: {e}")
    return edges


def initialize_graph(edges):
    """
    Converts edge list to an adjacency list and weights dictionary.
    Handles parallel edges by including edge_id as part of the structure.

    Args:
        edges (list): List of edges as (start, end, weight, edge_id).

    Returns:
        graph (dict): Adjacency list with (neighbor, edge_id) pairs.
        weights (dict): Dictionary mapping (start, end, edge_id) to weights.
    """
    graph = defaultdict(list)
    weights = {}
    for u, v, w, edge_id in edges:
        graph[u].append((v, edge_id))
        weights[(u, v, edge_id)] = w
    return graph, weights


def find_cycles_and_reduce(graph, weights, n):
    """
    Phase 1: Find cycles and reduce weights using a copy.
    Handles graphs with parallel edges by considering edge identifiers.

    Args:
        graph (dict): Adjacency list with (neighbor, edge_id) pairs.
        weights (dict): Dictionary mapping (u, v, edge_id) to weights.
        n (int): Number of vertices in the graph.

    Returns:
        removed_edges (set): Set of removed edges as (u, v, edge_id).
        removed_weights (dict): Dictionary of removed edges with their original weights.
    """
    weights_copy = weights.copy()  # Work with a copy of weights
    removed_edges = set()
    removed_weights = {}

    while True:
        cycle = find_cycle(graph, n)  # Modified `find_cycle` returns edges with edge_id
        if not cycle:  # No cycle found
            break

        # Ensure all edges in the cycle exist in the weights dictionary
        cycle = [(u, v, edge_id) for u, v, edge_id in cycle if (u, v, edge_id) in weights_copy]

        if not cycle:  # If no valid cycle exists, continue
            continue

        # Find the minimum weight in the cycle
        min_weight = min(weights_copy[(u, v, edge_id)] for u, v, edge_id in cycle)

        for u, v, edge_id in cycle:
            weights_copy[(u, v, edge_id)] -= min_weight
            if weights_copy[(u, v, edge_id)] <= 0:
                # Ensure the edge is in the graph before removing
                if (v, edge_id) in graph[u]:
                    graph[u].remove((v, edge_id))
                    removed_edges.add((u, v, edge_id))
                    removed_weights[(u, v, edge_id)] = weights[(u, v, edge_id)]

    return removed_edges, removed_weights

from collections import deque

def find_cycle(graph, n):
    """
    Detect a cycle in the graph using DFS and return the cycle as a list of edges.
    Handles parallel edges and cycles of length 2 caused by reverse edges.

    Args:
        graph (dict): Adjacency list with (neighbor, edge_id) pairs.
        n (int): Number of vertices in the graph.

    Returns:
        cycle (list): List of edges forming the cycle, or None if no cycle is found.
    """
    visited = [False] * n
    stack = [False] * n
    parent = [-1] * n
    edge_to_parent = {}  # Map to track edge_id for cycle reconstruction

    def dfs(v):
        visited[v] = True
        stack[v] = True
        for neighbor, edge_id in graph[v]:
            if not visited[neighbor]:
                parent[neighbor] = v
                edge_to_parent[neighbor] = edge_id
                cycle = dfs(neighbor)
                if cycle:
                    return cycle
            elif stack[neighbor]:
                # Found a cycle, reconstruct it
                cycle = []
                current = v
                while current != neighbor:
                    if current not in edge_to_parent:
                        break  # Avoid KeyError if edge metadata is missing
                    cycle.append((parent[current], current, edge_to_parent[current]))
                    current = parent[current]

                # Handle the root of the cycle
                if neighbor in edge_to_parent and parent[neighbor] != -1:
                    cycle.append((parent[neighbor], neighbor, edge_to_parent[neighbor]))
                return cycle

        stack[v] = False
        return None

    # Detect length-2 cycles caused by reverse edges
    for u in list(graph):  # Use list(graph) to iterate over a static copy of keys
        for neighbor, edge_id1 in graph[u]:
            for neighbor_of_neighbor, edge_id2 in graph[neighbor]:
                if neighbor_of_neighbor == u and edge_id1 != edge_id2:
                    # Found a length-2 cycle
                    return [(u, neighbor, edge_id1), (neighbor, u, edge_id2)]

    # Run DFS for longer cycles
    for i in range(n):
        if not visited[i]:
            cycle = dfs(i)
            if cycle:
                return cycle

    return None


def update_edge_weights(graph, weights):
    """
    Updates the weights of the edges in the graph based on the specified rule.
    If both (i, j) and (j, i) edges exist, the smaller weight is removed, and the larger weight is updated to:
    w_{i,j} / (w_{i,j} + w_{j,i}).
    If only one edge exists, its weight is updated to 1.

    Args:
        graph (dict): Adjacency list with (neighbor, edge_id) pairs.
        weights (dict): Dictionary mapping (start, end, edge_id) to weights.

    Returns:
        updated_graph (dict): Updated adjacency list.
        updated_weights (dict): Updated weights dictionary.
    """
    processed_edges = set()  # Keep track of processed edges
    updated_graph = defaultdict(list)
    updated_weights = {}

    # Iterate over a copy of the graph's keys to avoid modification during iteration
    for u in list(graph.keys()):
        for v, edge_id in graph[u]:
            if (u, v, edge_id) not in processed_edges:
                reverse_edge = next(
                    ((w, rev_edge_id) for w, rev_edge_id in graph[v] if w == u),
                    None
                )
                if reverse_edge:
                    # Get reverse edge weight
                    rev_edge_id = reverse_edge[1]
                    w_uv = weights[(u, v, edge_id)]
                    w_vu = weights[(v, u, rev_edge_id)]

                    if w_uv >= w_vu:
                        # Update weight of (u, v)
                        updated_weight = w_uv / (w_uv + w_vu)
                        updated_graph[u].append((v, edge_id))
                        updated_weights[(u, v, edge_id)] = updated_weight
                        # Mark (v, u) as processed
                        processed_edges.add((v, u, rev_edge_id))
                    else:
                        # Update weight of (v, u)
                        updated_weight = w_vu / (w_uv + w_vu)
                        updated_graph[v].append((u, rev_edge_id))
                        updated_weights[(v, u, rev_edge_id)] = updated_weight
                        # Mark (u, v) as processed
                        processed_edges.add((u, v, edge_id))
                else:
                    # No reverse edge, update the weight to 1
                    updated_graph[u].append((v, edge_id))
                    updated_weights[(u, v, edge_id)] = 1.0

                # Mark this edge as processed
                processed_edges.add((u, v, edge_id))

    return updated_graph, updated_weights




from collections import deque

import numpy as np

def find_minimum_weight_cycle(graph, weights, n):
    """
    Find the minimum weight cycle in the graph using Floyd-Warshall.

    :param graph: Adjacency list representation of the graph.
    :param weights: Dictionary of edge weights.
    :param n: Total number of vertices in the graph.
    :return: List of edges representing the minimum weight cycle.
    """
    # Step 1: Initialize distance and predecessor matrices
    dist = np.full((n, n), float('inf'))
    pred = [[-1 for _ in range(n)] for _ in range(n)]

    # Fill in the distances based on edge weights
    for u in range(n):
        dist[u][u] = 0
        if u in graph:
            for v in graph[u]:
                dist[u][v] = weights.get((u, v), float('inf'))
                pred[u][v] = u

    # Step 2: Run Floyd-Warshall algorithm
    for k in range(n):
        for i in range(n):
            for j in range(n):
                if dist[i][j] > dist[i][k] + dist[k][j]:
                    dist[i][j] = dist[i][k] + dist[k][j]
                    pred[i][j] = pred[k][j]

    # Step 3: Find the minimum weight cycle
    min_cycle_weight = float('inf')
    cycle = []

    for u in range(n):
        for v in range(n):
            if u != v and dist[u][v] < float('inf') and dist[v][u] < float('inf'):
                cycle_weight = dist[u][v] + dist[v][u]
                if cycle_weight < min_cycle_weight:
                    min_cycle_weight = cycle_weight
                    # Reconstruct the cycle
                    cycle = []
                    # Trace path from u to v
                    current = v
                    while current != u:
                        cycle.append((pred[u][current], current))
                        current = pred[u][current]
                    # Trace path from v back to u
                    current = u
                    while current != v:
                        cycle.append((pred[v][current], current))
                        current = pred[v][current]

    # Return the minimum weight cycle if found
    if min_cycle_weight == float('inf'):
        return None
    else:
        return cycle


def check_and_readd_edges(graph, removed_edges, n):
    """
    Phase 2: Check and re-add edges if they do not create a cycle.
    Handles graphs with parallel edges using edge identifiers.

    Args:
        graph (dict): Adjacency list with (neighbor, edge_id) pairs.
        removed_edges (set): Set of removed edges as (u, v, edge_id).
        n (int): Number of vertices in the graph.

    Returns:
        readded_edges (set): Set of edges that were successfully re-added.
        remaining_removed_edges (set): Set of edges that could not be re-added.
    """
    
    def has_path(start, end, graph):
        """
        Helper function to check if there is a path from start to end using DFS.
        Avoids cycles when re-adding edges.
        """
        visited = [False] * n
        stack = [start]
        while stack:
            node = stack.pop()
            if node == end:
                return True
            if not visited[node]:
                visited[node] = True
                stack.extend(neighbor for neighbor, _ in graph[node])  # Add only neighbors
        return False

    readded_edges = set()
    removed_edges_list = sorted(list(removed_edges), reverse=True)

    for u, v, edge_id in removed_edges_list:
        if not has_path(v, u, graph):  # Only re-add if it doesn't create a cycle
            graph[u].append((v, edge_id))
            readded_edges.add((u, v, edge_id))

    remaining_removed_edges = removed_edges - readded_edges
    return readded_edges, remaining_removed_edges

def mwfas(file_path):
    """
    Main function to find Minimum Weighted Feedback Arc Set (MWFAS) in a graph with parallel edges.
    
    :param file_path: Path to the file containing the graph.
    :return: A dictionary with metrics, updated graph, removed edges, and their weights.
    """
    # Read the graph and initialize its structure
    edges = read_graph(file_path)
    n = max(max(u, v) for u, v, _, _ in edges) + 1
    graph, weights = initialize_graph(edges)

    # Original graph statistics
    total_edges = len(edges)
    total_weight = sum(w for _, _, w, _ in edges)

    # Phase 1: Reduce cycles
    removed_edges, removed_weights = find_cycles_and_reduce(graph, weights, n)

    # Phase 2: Re-add edges (if applicable)
    readded_edges, remaining_removed_edges = check_and_readd_edges(graph, removed_edges, n)

    # Compute final metrics
    num_removed_edges = len(remaining_removed_edges)
    total_removed_weight = sum(removed_weights.get(edge, 0) for edge in remaining_removed_edges)

    # Return results
    return {
        "total_edges": total_edges,
        "total_weight": total_weight,
        "num_removed_edges": num_removed_edges,
        "removed_weight": total_removed_weight,
        "final_graph": graph,
        "removed_edges": remaining_removed_edges,
        "removed_weights": {edge: removed_weights.get(edge, 0) for edge in remaining_removed_edges},
    }

    

# Example usage

# %%
import random
from collections import defaultdict, deque


class DirectedGraph:
    def __init__(self, vertices):
        self.graph = defaultdict(list)
        self.vertices = vertices
        self.weights = {}  # Maintain weights dictionary with unique edge keys

    def add_edge(self, src, dest, weight=1, edge_id=None):
        """
        Add a directed edge with weight and an optional unique edge_id.
        """
        if edge_id is None:
            edge_id = (src, dest, len(self.graph[src]))  # Generate unique edge_id
        self.graph[src].append((dest, edge_id))
        self.weights[(src, dest, edge_id)] = weight

    def get_edges(self):
        edges = []
        for src in self.graph:
            for dest, edge_id in self.graph[src]:
                edges.append((src, dest, self.weights[(src, dest, edge_id)]))
        return edges

    def remove_edge(self, src, dest):
        self.graph[src] = [(d, eid) for d, eid in self.graph[src] if d != dest]
        self.weights = {key: weight for key, weight in self.weights.items() if key[0] != src or key[1] != dest}

    def get_indegree(self):
        indegree = {v: 0 for v in range(self.vertices)}
        for src in self.graph:
            for dest, _ in self.graph[src]:
                indegree[dest] += 1
        return indegree

    def get_outdegree(self):
        outdegree = {v: 0 for v in range(self.vertices)}
        for src in self.graph:
            for dest, _ in self.graph[src]:
                outdegree[src] += 1
        return outdegree

    def eliminate_parallel_arcs(self):
        for src in self.graph:
            seen = {}
            for dest, weight in self.graph[src]:
                if dest in seen:
                    seen[dest] += self.weights[(src, dest, weight)]
                else:
                    seen[dest] = self.weights[(src, dest, weight)]
            self.graph[src] = [(dest, weight) for dest, weight in seen.items()]

    def eliminate_two_cycles(self):
        for src in list(self.graph.keys()):
            for dest, weight in self.graph[src]:
                for back_dest, back_weight in self.graph[dest]:
                    if back_dest == src:
                        if weight > back_weight:
                            self.remove_edge(src, dest)
                            self.remove_edge(dest, src)
                        elif weight == back_weight:
                            self.remove_edge(src, dest)
                            self.remove_edge(dest, src)

# %%
def mwfas2(file_path):
    """
    Computes a feedback arc set for a graph, removes the edges in the FAS, and returns the resulting DAG.

    Args:
        file_path (str): Path to the file containing the graph.

    Returns:
        dict: Contains the final DAG, removed edges, and related metrics.
    """
    # Step 1: Read the graph
    edges = read_graph(file_path)
    n = max(max(u, v) for u, v, _, _ in edges) + 1
    graph, weights = initialize_graph(edges)

    # Step 2: Graph reduction (similar to fas_red.cpp)
    reduced_graph = reduce_graph(graph, weights)

    # Step 3: Compute FAS using a heuristic (similar to fas_alg.cpp)
    feedback_arc_set, removed_weights = compute_feedback_arc_set(reduced_graph, weights)

    # Step 4: Remove FAS edges from the graph
    for u, v, edge_id in feedback_arc_set:
        reduced_graph[u] = [
            (neighbor, eid) for neighbor, eid in reduced_graph[u]
            if not (neighbor == v and eid == edge_id)
        ]

    # Step 5: Return results
    return {
        "final_graph": reduced_graph,
        "removed_edges": feedback_arc_set,
        "removed_weights": removed_weights,
        "total_removed_weight": sum(removed_weights.values()),
    }


def reduce_graph(graph, weights):
    """
    Simplifies the graph by removing trivial components like sinks and sources.

    Args:
        graph (dict): Adjacency list.
        weights (dict): Edge weights.

    Returns:
        dict: Reduced graph.
    """
    # Remove sinks and sources
    while True:
        sinks = [u for u in graph if len(graph[u]) == 0]
        sources = [u for u in graph if all(u not in [v for v, _ in graph[u2]] for u2 in graph)]

        if not sinks and not sources:
            break

        for sink in sinks:
            graph.pop(sink, None)

        for source in sources:
            graph.pop(source, None)

    return graph


def compute_feedback_arc_set(graph, weights):
    """
    Computes a feedback arc set using a heuristic.

    Args:
        graph (dict): Adjacency list.
        weights (dict): Edge weights.

    Returns:
        list: Feedback arc set (list of edges).
        dict: Weights of removed edges.
    """
    feedback_arc_set = []
    removed_weights = {}

    # Ensure in_degree includes all nodes
    in_degree = {u: 0 for u in range(max(graph.keys(), default=-1) + 1)}
    for u in graph:
        for v, _ in graph[u]:
            if v not in in_degree:
                in_degree[v] = 0
            in_degree[v] += 1

    # Topological sort with cycle detection
    queue = deque([u for u in in_degree if in_degree[u] == 0])
    order = []

    while queue:
        u = queue.popleft()
        order.append(u)
        for v, edge_id in graph.get(u, []):  # Handle cases where u might not have outgoing edges
            in_degree[v] -= 1
            if in_degree[v] == 0:
                queue.append(v)

    # Identify cycles and select edges to remove
    for u in graph:
        for v, edge_id in graph[u]:
            if u in order and v in order and order.index(u) > order.index(v):
                edge_key = (u, v, edge_id)
                feedback_arc_set.append(edge_key)
                removed_weights[edge_key] = weights[edge_key]

    return feedback_arc_set, removed_weights

# %%
def compute_vertex_rankings(graph, weights, n):
    """
    Compute rankings for the vertices in a DAG with parallel edges.
    :param graph: Adjacency list of the DAG with (neighbor, edge_id) pairs.
    :param weights: Dictionary of edge weights with keys (u, v, edge_id).
    :param n: Total number of vertices in the graph.
    :return: A list of rankings for the vertices.
    """
    # Step 1: Calculate in-degrees
    in_degree = [0] * n
    for u in graph:
        for v, _ in graph[u]:  # Ignore edge_id for in-degree calculation
            in_degree[v] += 1

    # Step 2: Perform topological sort using a min-heap
    from heapq import heappop, heappush
    min_heap = []
    for i in range(n):
        if in_degree[i] == 0:
            heappush(min_heap, i)

    topological_order = []
    while min_heap:
        current = heappop(min_heap)
        topological_order.append(current)
        for neighbor, _ in graph[current]:  # Ignore edge_id for topological sort
            in_degree[neighbor] -= 1
            if in_degree[neighbor] == 0:
                heappush(min_heap, neighbor)

    # Step 3: Calculate outgoing and incoming edge weight sums for all vertices
    outgoing_weights = {v: 0 for v in range(n)}
    incoming_weights = {v: 0 for v in range(n)}

    for u in graph:
        for v, edge_id in graph[u]:
            edge_key = (u, v, edge_id)
            outgoing_weights[u] += weights.get(edge_key, 0)
            incoming_weights[v] += weights.get(edge_key, 0)

    # Step 4: Assign rankings
    rankings = [-1] * n
    current_rank = 0
    for vertex in topological_order:
        rankings[vertex] = current_rank
        current_rank += 1

    # Break ties for vertices with the same ranking based on outgoing and incoming edge weights
    tied_vertices = sorted(
        [(rankings[v], -(outgoing_weights[v] - incoming_weights[v]) / 
          (outgoing_weights[v] + incoming_weights[v] if outgoing_weights[v] + incoming_weights[v] > 0 else 1), v)
         for v in range(n)],
        key=lambda x: (x[0], x[1])  # Sort by rank first, then by normalized weight difference
    )

    scores = [0] * n
    for final_rank, (_, _, vertex) in enumerate(tied_vertices):
        scores[vertex] = n - final_rank - 1

    return scores

# %%
# def optimize_updated_scores(adjacency_matrix, scores, epsilon=1e-8):
#     import cvxpy as cp
#     import numpy as np

#     n = len(scores)

#     # Convert inputs to numpy
#     adjacency_matrix_np = adjacency_matrix.numpy()
#     scores_np = scores.numpy().flatten()

#     # Define optimization variables
#     updated_scores = cp.Variable(n)
#     R = cp.Variable((n, n))  # Auxiliary variable for ratios

#     # Compute M (skew-symmetric pairwise matrix)
#     M = adjacency_matrix_np - adjacency_matrix_np.T

#     # Edge mask
#     edge_mask = (adjacency_matrix_np + adjacency_matrix_np.T > 0).astype(float)

#     # Objective: Minimize squared difference between M and R
#     objective = cp.sum_squares(cp.multiply(edge_mask, M - R))

#     # Constraints for R_ij
#     constraints = []
#     for i in range(n):
#         for j in range(n):
#             if edge_mask[i, j] > 0:
#                 constraints.append(R[i, j] * (updated_scores[i] + updated_scores[j] + epsilon) == updated_scores[i] - updated_scores[j])

#     # Order-preserving constraints
#     constraints += [
#         updated_scores[i] <= updated_scores[j]
#         for i in range(n)
#         for j in range(n)
#         if scores_np[i] <= scores_np[j]
#     ]

#     # Solve the problem
#     problem = cp.Problem(cp.Minimize(objective), constraints)
#     problem.solve()

#     return updated_scores.value

# %%
import torch

def graph_to_adjacency_matrix(graph, weights, n):
    """
    Convert the graph to an adjacency matrix with weights.
    :param graph: Adjacency list of the DAG with (neighbor, edge_id) pairs.
    :param weights: Dictionary of edge weights with keys (u, v, edge_id).
    :param n: Total number of vertices in the graph.
    :return: An adjacency matrix (n x n) with weights as a PyTorch tensor.
    """
    import torch
    adjacency_matrix = torch.zeros((n, n), dtype=torch.float32)

    for u in graph:
        for v, edge_id in graph[u]:
            edge_key = (u, v, edge_id)
            adjacency_matrix[u, v] = weights.get(edge_key, 0)

    return adjacency_matrix

# %%
import torch
import numpy as np

def reorder_floats(x):
    n = len(x)
    random_floats = np.random.uniform(0,  2*n/3, n)
    y = np.zeros(n)
    for idx, val in enumerate(np.argsort(x)):
        y[val] = sorted(random_floats)[idx]
    return y

def calculate_upset_loss(adjacency_matrix, scores, style='ratio', margin=0.01):
    """
    Calculate the upset loss for the graph rankings using adjacency matrix and scores.

    :param adjacency_matrix: Torch FloatTensor adjacency matrix (n x n).
    :param scores: Torch FloatTensor ranking scores (n x 1).
    :param style: Type of upset loss ('naive', 'simple', 'ratio', or 'margin').
    :param margin: Margin for margin loss (default: 0.01).
    :return: Torch FloatTensor upset loss value.
    """
    epsilon = 1e-8  # For numerical stability

    # Ensure scores are 2D
    if scores.ndim == 1:
        scores = scores.view(-1, 1)

    # Skew-symmetric pairwise comparison matrix (M)
    M1 = adjacency_matrix - adjacency_matrix.T

    # Normalize scores to [0, 1] range
    normalized_scores = scores

    # Pairwise score differences (T)
    T1 = normalized_scores - normalized_scores.T

    # Edge mask: Only consider meaningful edges (where M != 0)
    edge_mask = M1 != 0

    if style == 'ratio':
        min_upset = float('inf')  # Initialize with a large value
        
        for _ in range(40):
            # Generate reordered scores using reorder_floats
            if _==0:
                reordered_scores=scores
            else:
                reordered_scores = torch.FloatTensor(reorder_floats(scores.flatten().tolist()))
            reordered_scores = reordered_scores.view(-1, 1)

            # Compute T2 for normalized scores
            T2 = reordered_scores + reordered_scores.T + epsilon
            T = torch.div(T1, T2)
            M2 = adjacency_matrix + adjacency_matrix.T + epsilon
            M3 = torch.div(M1, M2)  # Normalize the adjacency matrix
            
            # Compute ratio-based upset loss for this iteration
            powers = torch.pow((M3 - T)[edge_mask], 2)
            upset_loss = torch.sum(powers) / torch.sum(edge_mask)

            # Track the minimum upset loss
            min_upset = min(min_upset, upset_loss.item())
        
        return torch.tensor(min_upset)

    elif style == 'naive':
        upset = torch.sum(torch.sign(T1[edge_mask]) != torch.sign(M1[edge_mask])) / torch.sum(edge_mask)

    elif style == 'simple':
        upset = torch.mean((torch.sign(T1[edge_mask]) - torch.sign(M1[edge_mask]))**2)

    elif style == 'margin':
        upset = torch.mean(torch.nn.functional.relu(-M1[edge_mask] * (T1[edge_mask] - margin)))

    else:
        raise ValueError(f"Unsupported style: {style}")

    return upset

# %%
import torch

def compute_ratio_upset_loss(adjacency_matrix, scores, epsilon=1e-8):
    """
    Compute the ratio upset loss for the graph rankings using adjacency matrix and scores.

    :param adjacency_matrix: Torch FloatTensor adjacency matrix (n x n).
    :param scores: Torch FloatTensor ranking scores (n x 1).
    :param epsilon: Small value for numerical stability (default: 1e-8).
    :return: Torch FloatTensor ratio upset loss value.
    """
    # Ensure scores are 2D
    if scores.ndim == 1:
        scores = scores.view(-1, 1)

    # Skew-symmetric pairwise comparison matrix (M)
    M1 = adjacency_matrix - adjacency_matrix.T

    # Pairwise score differences (T1)
    T1 = scores - scores.T

    # Edge mask: Only consider meaningful edges (where M1 != 0)
    edge_mask = M1 != 0

    # Compute T2 for normalized scores
    T2 = scores + scores.T + epsilon
    T = torch.div(T1, T2)

    # Normalize M1 using adjacency matrix
    M2 = adjacency_matrix + adjacency_matrix.T + epsilon
    M3 = torch.div(M1, M2)  # Normalize the adjacency matrix

    # Compute ratio upset loss
    powers = torch.pow((M3 - T)[edge_mask], 2)
    upset_loss = torch.sum(powers) / torch.sum(edge_mask)

    return upset_loss

# %%
def minimize_ratio_upset_loss(adjacency_matrix, scores, epsilon=1e-2, max_time=120):
    """
    Perform optimization to minimize the ratio upset loss, ensuring naive and simple losses do not worsen.
    :param adjacency_matrix: Torch FloatTensor adjacency matrix (n x n).
    :param scores: Initial scores for optimization.
    :param epsilon: Small value for numerical stability (default: 1e-2).
    :param max_time: Maximum time for optimization in seconds.
    :return: Tuple (optimal_scores, minimized_loss)
    """
    import numpy as np
    import torch
    from scipy.optimize import minimize
    import time

    n = adjacency_matrix.shape[0]

    # Compute initial losses
    initial_scores = scores.clone().detach().view(-1).numpy()
    initial_losses = {
        "naive": calculate_upset_loss(adjacency_matrix, scores.view(-1, 1), style="naive"),
        "simple": calculate_upset_loss(adjacency_matrix, scores.view(-1, 1), style="simple"),
    }

    # Objective function
    def objective_function(updated_scores, adjacency_matrix, initial_losses):
        updated_scores = torch.tensor(updated_scores, dtype=torch.float32).view(-1, 1)
        ratio_loss = calculate_upset_loss(adjacency_matrix, updated_scores, style="ratio")
        naive_loss = calculate_upset_loss(adjacency_matrix, updated_scores, style="naive")
        simple_loss = calculate_upset_loss(adjacency_matrix, updated_scores, style="simple")

        penalty = 0
        if naive_loss > initial_losses["naive"]:
            penalty += naive_loss - initial_losses["naive"]
        if simple_loss > initial_losses["simple"]:
            penalty += simple_loss - initial_losses["simple"]

        return ratio_loss + 100 * penalty

    # Timer callback
    class TimerCallback:
        def __init__(self, max_time, objective_function, adjacency_matrix, initial_losses):
            self.start_time = time.time()
            self.max_time = max_time
            self.iterations = 0  # Track iterations
            self.objective_function = objective_function
            self.adjacency_matrix = adjacency_matrix
            self.initial_losses = initial_losses
            self.min_loss = float("inf")  # Track minimum loss

        def __call__(self, xk, *args, **kwargs):
            self.iterations += 1

            # Compute the objective function value
            current_loss = self.objective_function(
                xk, self.adjacency_matrix, self.initial_losses
            )

            # Update and print the minimum loss found so far
            self.min_loss = min(self.min_loss, current_loss)
            print(f"Iteration {self.iterations}: Minimum loss so far: {self.min_loss:.6f}")

            # Stop optimization if the time limit is exceeded
            if time.time() - self.start_time > self.max_time:
                print("Time limit exceeded, stopping optimization.")
                raise StopIteration  # Signal COBYLA to stop

    # Create the callback instance
    callback = TimerCallback(
        max_time=max_time,
        objective_function=objective_function,
        adjacency_matrix=adjacency_matrix,
        initial_losses=initial_losses,
    )

    try:
        # Run optimization with COBYLA
        result = minimize(
            fun=objective_function,
            x0=initial_scores,
            method="COBYLA",
            args=(adjacency_matrix, initial_losses),  # Pass required arguments
            options={"maxiter": 500, "disp": False},
            callback=callback,  # Logs the minimum loss after each iteration
        )
    except StopIteration:
        print("Optimization stopped early due to time limit.")

    # Extract results
    optimal_scores = result.x
    minimized_loss = result.fun

    print(f"Optimization completed after {callback.iterations} iterations.")
    print(f"Final minimum loss: {callback.min_loss:.6f}")
    return optimal_scores, minimized_loss

# %%
import torch

import matplotlib.pyplot as plt
import os

def compute_ratio_upset_loss(adjacency_matrix, scores, epsilon=1e-8):
    """
    Compute the ratio upset loss for the graph rankings using adjacency matrix and scores.
    
    :param adjacency_matrix: Torch FloatTensor adjacency matrix (n x n).
    :param scores: Torch FloatTensor ranking scores (n x 1).
    :param epsilon: Small value for numerical stability (default: 1e-8).
    :return: Torch FloatTensor ratio upset loss value.
    """
    if scores.ndim == 1:
        scores = scores.view(-1, 1)

    M1 = adjacency_matrix - adjacency_matrix.T
    T1 = scores - scores.T
    edge_mask = M1 != 0

    T2 = scores + scores.T + epsilon
    T = torch.div(T1, T2)

    M2 = adjacency_matrix + adjacency_matrix.T + epsilon
    M3 = torch.div(M1, M2)

    powers = torch.pow((M3 - T)[edge_mask], 2)
    upset_loss = torch.sum(powers) / torch.sum(edge_mask)

    return upset_loss

import torch
import matplotlib.pyplot as plt
import os


def plot_ratio_loss(adjacency_matrix, scores, index, lower_bound, upper_bound, steps=100, output_folder="loss_plots"):
    """
    Plot and save the compute_ratio_upset_loss function for scores[index] between lower_bound and upper_bound.

    :param adjacency_matrix: Torch FloatTensor adjacency matrix (n x n).
    :param scores: Torch FloatTensor ranking scores (n x 1).
    :param index: Index of the score to vary.
    :param lower_bound: Lower bound for the score value.
    :param upper_bound: Upper bound for the score value.
    :param steps: Number of steps for sampling the range.
    :param output_folder: Directory to save the plots.
    """
    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    x_values = torch.linspace(lower_bound, upper_bound, steps)
    y_values = []

    original_score = scores[index].item()

    for x in x_values:
        scores[index] = x
        loss = compute_ratio_upset_loss(adjacency_matrix, scores)
        y_values.append(loss.item())

    # Restore the original score
    scores[index] = original_score

    # Plot the graph
    plt.figure(figsize=(8, 6))
    plt.plot(x_values.numpy(), y_values, label=f"Loss vs. scores[{index}]")
    plt.xlabel(f"scores[{index}] value")
    plt.ylabel("Ratio Upset Loss")
    plt.title(f"Compute Ratio Upset Loss for Varying scores[{index}]")
    plt.legend()
    plt.grid(True)

    # Save the plot with a unique name
    plot_path = os.path.join(output_folder, f"loss_plot_index_{index}.png")
    counter = 1
    while os.path.exists(plot_path):
        plot_path = os.path.join(output_folder, f"loss_plot_index_{index}_{counter}.png")
        counter += 1

    plt.savefig(plot_path)
    plt.close()

    print(f"Plot saved: {plot_path}")


def trinary_search_optimize(adjacency_matrix, scores, index, lower_bound, upper_bound, epsilon=1e-8, steps=100):
    print("hi")
    plot_ratio_loss(adjacency_matrix, scores, index, lower_bound, upper_bound, steps=100)
    """
    Perform binary search to find the optimal score value for a given index that minimizes ratio upset loss.

    :param adjacency_matrix: Torch FloatTensor adjacency matrix (n x n).
    :param scores: Torch FloatTensor ranking scores (n x 1).
    :param index: Index of the score to optimize.
    :param lower_bound: Lower bound for the score value.
    :param upper_bound: Upper bound for the score value.
    :param epsilon: Small value for numerical stability.
    :param steps: Number of steps for binary search.
    :return: Optimal score value for the given index.
    """
    for _ in range(steps):
        mid1 = lower_bound + (upper_bound - lower_bound) / 3
        mid2 = upper_bound - (upper_bound - lower_bound) / 3

        scores[index] = mid1
        loss1 = compute_ratio_upset_loss(adjacency_matrix, scores)

        scores[index] = mid2
        loss2 = compute_ratio_upset_loss(adjacency_matrix, scores)

        if loss1 < loss2:
            upper_bound = mid2
        else:
            lower_bound = mid1

    # Set the score to the midpoint of the final range
    scores[index] = (lower_bound + upper_bound) / 2
    return scores[index]

from scipy.optimize import minimize_scalar
import torch




def minimize_ratio_loss(adjacency_matrix, scores):
    """
    Minimize the ratio upset loss by iteratively optimizing each score using binary search.

    :param adjacency_matrix: Torch FloatTensor adjacency matrix (n x n).
    :param scores: Torch FloatTensor ranking scores (n x 1).
    :return: Optimized scores.
    """
    scores = scores.clone()  # Create a copy to avoid modifying the original

    for _ in range(40):
        sorted_indices = torch.argsort(scores.squeeze())
        print(_)
        for i in range(len(sorted_indices)):
            
            
            
            index = sorted_indices[i]

            if i == 0:
                lower_bound = 0
                upper_bound = scores[sorted_indices[i + 1]].item()
            elif i == len(sorted_indices) - 1:
                lower_bound = scores[sorted_indices[i - 1]].item()
                upper_bound = scores.max().item() + 10  # Extend beyond max for the last element
            else:
                lower_bound = scores[sorted_indices[i - 1]].item()
                upper_bound = scores[sorted_indices[i + 1]].item()

            # Perform binary search optimization for the current score
            scores[index] = trinary_search_optimize(adjacency_matrix, scores, index, lower_bound, upper_bound)
            print("i am here")
    return scores

# Example usage

# %%
def evaluate_upset_losses(file_path, rankings):
    """
    Evaluate upset losses (naive, simple, ratio, margin) for a graph and given rankings.

    :param file_path: Path to the graph file.
    :param rankings: List of rankings for the vertices.
    """
    # Step 1: Prepare Graph and Adjacency Matrix
    edges = read_graph(file_path)
    n = max(max(u, v) for u, v, _ in edges) + 1
    graph, weights = initialize_graph(edges)
    adjacency_matrix = graph_to_adjacency_matrix(graph, weights, n)

    # Step 2: Convert Rankings to Scores Tensor
    scores = torch.FloatTensor(rankings).view(-1, 1)

    # Step 3: Calculate Upset Losses
    naive_loss = calculate_upset_loss(adjacency_matrix, scores, style='naive').item()
    simple_loss = calculate_upset_loss(adjacency_matrix, scores, style='simple').item()
    ratio_loss = calculate_upset_loss(adjacency_matrix, scores, style='ratio').item()
    margin_loss = calculate_upset_loss(adjacency_matrix, scores, style='margin').item()

    # Step 4: Print Results
    print("Upset Losses for the Graph Rankings:")
    print(f"Naive Upset Loss: {naive_loss:.4f}")
    print(f"Simple Upset Loss: {simple_loss:.4f}")
    print(f"Differentiable Upset Loss (Ratio): {ratio_loss:.4f}")
    print(f"Upset Margin Loss: {margin_loss:.4f}")

# %%
# Main Execution
import time
import pandas as pd

import torch

# List of input files
file_paths = ["England 2009 2010.txt"]


# Initialize results storage
results = []

# Iterate through each input file
for file_path in file_paths:
    start_time = time.time()

    # Step 1: Read the graph and initialize structures
    edges = read_graph(file_path)
    n = max(max(u, v) for u, v, _, _ in edges) + 1
    print(f"Processing file: {file_path} - Number of nodes: {n}, Number of edges: {len(edges)}")

    init_graph, init_weights = initialize_graph(edges)
#    init_graph, init_weights =update_edge_weights(init_graph,init_weights)
#    print(init_weights)
    # Step 2: Ensure the graph is a DAG by removing cycles
    result = mwfas(file_path)
    new_graph = result['final_graph']
    new_weights = {key: value for key, value in init_weights.items() if key not in result['removed_weights']}

    # Step 3: Compute rankings for the vertices using the modified graph
    final_rankings = compute_vertex_rankings(new_graph, new_weights, n)

    # Step 4: Evaluate upset losses before optimization
    scores = torch.FloatTensor(final_rankings).view(-1, 1)
    adjacency_matrix = graph_to_adjacency_matrix(init_graph, init_weights, n)

    print("Evaluating losses before optimization...")
    naive_loss_before = calculate_upset_loss(adjacency_matrix, scores, style='naive')
    simple_loss_before = calculate_upset_loss(adjacency_matrix, scores, style='simple')
    ratio_loss_before = calculate_upset_loss(adjacency_matrix, scores, style='ratio')
    end_time = time.time()
    elapsed_time = end_time - start_time
    print("Before Optimization:")
    print(f"Naive Loss: {naive_loss_before}")
    print(f"Simple Loss: {simple_loss_before}")
    print(f"Ratio Loss: {ratio_loss_before}")
    print(f"Elapsed Time: {elapsed_time:.4f} seconds")
#   Step 5: Perform optimization
    optimized_scores = minimize_ratio_loss(adjacency_matrix, scores)
    optimized_scores = torch.FloatTensor(optimized_scores).view(-1, 1)  # Ensure Torch Tensor format

 #   Step 6: Evaluate upset losses after optimization
    print("Evaluating losses after optimization...")
    naive_loss_after = calculate_upset_loss(adjacency_matrix, optimized_scores, style='naive')
    simple_loss_after = calculate_upset_loss(adjacency_matrix, optimized_scores, style='simple')
    ratio_loss_after = calculate_upset_loss(adjacency_matrix, optimized_scores, style='ratio')

   # end_time = time.time()
   # elapsed_time = end_time - start_time

    # Step 7: Print final results
    print("After Optimization:")
    print(f"Naive Loss: {naive_loss_after}")
    print(f"Simple Loss: {simple_loss_after}")
    print(f"Ratio Loss: {ratio_loss_after}")
  # print(f"Elapsed Time: {elapsed_time:.4f} seconds")

   
    
    #Store results in a list
#     results.append({
#         "File": "Football_finer("+str(file_path[13:17])+')',
#         "Nodes": n,
#         "Edges": len(edges),
#         "Naive Loss": round(naive_loss_before.item(),2),
#         "Simple Loss": round(simple_loss_before.item(),2),
#         "Ratio Loss": round(ratio_loss_before.item(),2),
#         "Elapsed Time (s)": round(elapsed_time,2)
#     })


# #Write results to an Excel file
# output_file = "finer_Football_results.xlsx"
# df = pd.DataFrame(results)
# df.to_excel(output_file, index=False)

# print(f"Results written to {output_file}")
# Out:
# Processing file: England 2009 2010.txt - Number of nodes: 20, Number of edges: 164
# Evaluating losses before optimization...
# Before Optimization:
# Naive Loss: 0.13414634764194489
# Simple Loss: 0.5365853905677795
# Ratio Loss: 0.6182869672775269
# Elapsed Time: 0.0321 seconds
# 0
# hi
# Plot saved: loss_plots/loss_plot_index_8.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18.png
# i am here
# 1
# hi
# Plot saved: loss_plots/loss_plot_index_8_1.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_1.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_1.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_1.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_1.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_1.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_1.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_1.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_1.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_1.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_1.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_1.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_1.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_1.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_1.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_1.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_1.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_1.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_1.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_1.png
# i am here
# 2
# hi
# Plot saved: loss_plots/loss_plot_index_8_2.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_2.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_2.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_2.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_2.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_2.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_2.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_2.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_2.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_2.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_2.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_2.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_2.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_2.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_2.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_2.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_2.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_2.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_2.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_2.png
# i am here
# 3
# hi
# Plot saved: loss_plots/loss_plot_index_8_3.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_3.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_3.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_3.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_3.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_3.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_3.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_3.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_3.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_3.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_3.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_3.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_3.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_3.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_3.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_3.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_3.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_3.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_3.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_3.png
# i am here
# 4
# hi
# Plot saved: loss_plots/loss_plot_index_8_4.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_4.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_4.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_4.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_4.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_4.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_4.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_4.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_4.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_4.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_4.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_4.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_4.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_4.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_4.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_4.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_4.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_4.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_4.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_4.png
# i am here
# 5
# hi
# Plot saved: loss_plots/loss_plot_index_8_5.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_5.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_5.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_5.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_5.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_5.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_5.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_5.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_5.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_5.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_5.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_5.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_5.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_5.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_5.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_5.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_5.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_5.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_5.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_5.png
# i am here
# 6
# hi
# Plot saved: loss_plots/loss_plot_index_8_6.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_6.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_6.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_6.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_6.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_6.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_6.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_6.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_6.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_6.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_6.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_6.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_6.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_6.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_6.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_6.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_6.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_6.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_6.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_6.png
# i am here
# 7
# hi
# Plot saved: loss_plots/loss_plot_index_8_7.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_7.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_7.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_7.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_7.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_7.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_7.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_7.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_7.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_7.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_7.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_7.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_7.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_7.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_7.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_7.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_7.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_7.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_7.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_7.png
# i am here
# 8
# hi
# Plot saved: loss_plots/loss_plot_index_8_8.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_8.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_8.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_8.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_8.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_8.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_8.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_8.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_8.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_8.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_8.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_8.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_8.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_8.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_8.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_8.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_8.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_8.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_8.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_8.png
# i am here
# 9
# hi
# Plot saved: loss_plots/loss_plot_index_8_9.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_9.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_9.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_9.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_9.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_9.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_9.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_9.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_9.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_9.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_9.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_9.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_9.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_9.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_9.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_9.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_9.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_9.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_9.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_9.png
# i am here
# 10
# hi
# Plot saved: loss_plots/loss_plot_index_8_10.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_10.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_10.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_10.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_10.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_10.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_10.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_10.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_10.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_10.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_10.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_10.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_10.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_10.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_10.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_10.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_10.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_10.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_10.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_10.png
# i am here
# 11
# hi
# Plot saved: loss_plots/loss_plot_index_8_11.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_11.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_11.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_11.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_11.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_11.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_11.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_11.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_11.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_11.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_11.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_11.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_11.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_11.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_11.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_11.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_11.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_11.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_11.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_11.png
# i am here
# 12
# hi
# Plot saved: loss_plots/loss_plot_index_8_12.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_12.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_12.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_12.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_12.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_12.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_12.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_12.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_12.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_12.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_12.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_12.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_12.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_12.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_12.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_12.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_12.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_12.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_12.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_12.png
# i am here
# 13
# hi
# Plot saved: loss_plots/loss_plot_index_8_13.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_13.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_13.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_13.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_13.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_13.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_13.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_13.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_13.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_13.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_13.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_13.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_13.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_13.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_13.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_13.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_13.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_13.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_13.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_13.png
# i am here
# 14
# hi
# Plot saved: loss_plots/loss_plot_index_8_14.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_14.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_14.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_14.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_14.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_14.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_14.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_14.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_14.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_14.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_14.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_14.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_14.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_14.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_14.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_14.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_14.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_14.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_14.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_14.png
# i am here
# 15
# hi
# Plot saved: loss_plots/loss_plot_index_8_15.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_15.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_15.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_15.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_15.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_15.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_15.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_15.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_15.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_15.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_15.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_15.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_15.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_15.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_15.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_15.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_15.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_15.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_15.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_15.png
# i am here
# 16
# hi
# Plot saved: loss_plots/loss_plot_index_8_16.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_16.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_16.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_16.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_16.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_16.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_16.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_16.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_16.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_16.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_16.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_16.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_16.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_16.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_16.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_16.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_16.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_16.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_16.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_16.png
# i am here
# 17
# hi
# Plot saved: loss_plots/loss_plot_index_8_17.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_17.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_17.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_17.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_17.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_17.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_17.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_17.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_17.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_17.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_17.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_17.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_17.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_17.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_17.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_17.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_17.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_17.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_17.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_17.png
# i am here
# 18
# hi
# Plot saved: loss_plots/loss_plot_index_8_18.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_18.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_18.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_18.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_18.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_18.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_18.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_18.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_18.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_18.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_18.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_18.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_18.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_18.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_18.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_18.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_18.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_18.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_18.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_18.png
# i am here
# 19
# hi
# Plot saved: loss_plots/loss_plot_index_8_19.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_19.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_19.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_19.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_19.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_19.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_19.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_19.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_19.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_19.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_19.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_19.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_19.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_19.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_19.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_19.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_19.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_19.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_19.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_19.png
# i am here
# 20
# hi
# Plot saved: loss_plots/loss_plot_index_8_20.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_20.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_20.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_20.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_20.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_20.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_20.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_20.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_20.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_20.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_20.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_20.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_20.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_20.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_20.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_20.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_20.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_20.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_20.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_20.png
# i am here
# 21
# hi
# Plot saved: loss_plots/loss_plot_index_8_21.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_21.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_21.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_21.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_21.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_21.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_21.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_21.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_21.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_21.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_21.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_21.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_21.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_21.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_21.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_21.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_21.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_21.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_21.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_21.png
# i am here
# 22
# hi
# Plot saved: loss_plots/loss_plot_index_8_22.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_22.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_22.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_22.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_22.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_22.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_22.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_22.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_22.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_22.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_22.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_22.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_22.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_22.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_22.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_22.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_22.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_22.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_22.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_22.png
# i am here
# 23
# hi
# Plot saved: loss_plots/loss_plot_index_8_23.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_23.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_23.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_23.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_23.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_23.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_23.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_23.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_23.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_23.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_23.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_23.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_23.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_23.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_23.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_23.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_23.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_23.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_23.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_23.png
# i am here
# 24
# hi
# Plot saved: loss_plots/loss_plot_index_8_24.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_24.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_24.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_24.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_24.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_24.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_24.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_24.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_24.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_24.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_24.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_24.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_24.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_24.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_24.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_24.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_24.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_24.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_24.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_24.png
# i am here
# 25
# hi
# Plot saved: loss_plots/loss_plot_index_8_25.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_25.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_25.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_25.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_25.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_25.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_25.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_25.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_25.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_25.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_25.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_25.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_25.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_25.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_25.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_25.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_25.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_25.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_25.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_25.png
# i am here
# 26
# hi
# Plot saved: loss_plots/loss_plot_index_8_26.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_26.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_26.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_26.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_26.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_26.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_26.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_26.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_26.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_26.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_26.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_26.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_26.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_26.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_26.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_26.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_26.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_26.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_26.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_26.png
# i am here
# 27
# hi
# Plot saved: loss_plots/loss_plot_index_8_27.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_27.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_27.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_27.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_27.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_27.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_27.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_27.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_27.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_27.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_27.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_27.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_27.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_27.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_27.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_27.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_27.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_27.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_27.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_27.png
# i am here
# 28
# hi
# Plot saved: loss_plots/loss_plot_index_8_28.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_28.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_28.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_28.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_28.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_28.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_28.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_28.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_28.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_28.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_28.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_28.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_28.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_28.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_28.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_28.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_28.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_28.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_28.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_28.png
# i am here
# 29
# hi
# Plot saved: loss_plots/loss_plot_index_8_29.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_29.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_29.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_29.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_29.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_29.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_29.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_29.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_29.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_29.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_29.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_29.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_29.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_29.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_29.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_29.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_29.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_29.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_29.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_29.png
# i am here
# 30
# hi
# Plot saved: loss_plots/loss_plot_index_8_30.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_30.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_30.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_30.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_30.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_30.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_30.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_30.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_30.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_30.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_30.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_30.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_30.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_30.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_30.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_30.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_30.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_30.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_30.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_30.png
# i am here
# 31
# hi
# Plot saved: loss_plots/loss_plot_index_8_31.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_31.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_31.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_31.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_31.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_31.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_31.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_31.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_31.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_31.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_31.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_31.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_31.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_31.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_31.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_31.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_31.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_31.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_31.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_31.png
# i am here
# 32
# hi
# Plot saved: loss_plots/loss_plot_index_8_32.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_32.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_32.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_32.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_32.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_32.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_32.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_32.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_32.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_32.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_32.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_32.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_32.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_32.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_32.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_32.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_32.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_32.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_32.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_32.png
# i am here
# 33
# hi
# Plot saved: loss_plots/loss_plot_index_8_33.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_33.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_33.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_33.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_33.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_33.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_33.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_33.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_33.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_33.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_33.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_33.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_33.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_33.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_33.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_33.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_33.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_33.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_33.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_33.png
# i am here
# 34
# hi
# Plot saved: loss_plots/loss_plot_index_8_34.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_34.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_34.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_34.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_34.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_34.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_34.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_34.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_34.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_34.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_34.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_34.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_34.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_34.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_34.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_34.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_34.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_34.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_34.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_34.png
# i am here
# 35
# hi
# Plot saved: loss_plots/loss_plot_index_8_35.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_35.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_35.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_35.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_35.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_35.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_35.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_35.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_35.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_35.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_35.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_35.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_35.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_35.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_35.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_35.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_35.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_35.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_35.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_35.png
# i am here
# 36
# hi
# Plot saved: loss_plots/loss_plot_index_8_36.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_36.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_36.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_36.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_36.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_36.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_36.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_36.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_36.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_36.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_36.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_36.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_36.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_36.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_36.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_36.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_36.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_36.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_36.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_36.png
# i am here
# 37
# hi
# Plot saved: loss_plots/loss_plot_index_8_37.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_37.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_37.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_37.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_37.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_37.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_37.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_37.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_37.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_37.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_37.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_37.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_37.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_37.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_37.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_37.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_37.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_37.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_37.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_37.png
# i am here
# 38
# hi
# Plot saved: loss_plots/loss_plot_index_8_38.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_38.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_38.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_38.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_38.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_38.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_38.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_38.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_38.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_38.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_38.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_38.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_38.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_38.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_38.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_38.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_38.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_38.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_38.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_38.png
# i am here
# 39
# hi
# Plot saved: loss_plots/loss_plot_index_8_39.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_7_39.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_19_39.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_10_39.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_3_39.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_0_39.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_6_39.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_5_39.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_9_39.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_13_39.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_17_39.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_4_39.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_1_39.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_15_39.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_16_39.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_14_39.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_11_39.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_2_39.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_12_39.png
# i am here
# hi
# Plot saved: loss_plots/loss_plot_index_18_39.png
# i am here
# Evaluating losses after optimization...
# After Optimization:
# Naive Loss: 0.13414634764194489
# Simple Loss: 0.5365853905677795
# Ratio Loss: 0.52874356508255

# %%
results = []



# Iterate through each input file
for file_path in file_paths:
    start_time = time.time()

    # Step 1: Read the graph and initialize structures
    edges = read_graph(file_path)
    n = max(max(u, v) for u, v, _, _ in edges) + 1
    print(f"Processing file: {file_path} - Number of nodes: {n}, Number of edges: {len(edges)}")

    init_graph, init_weights = initialize_graph(edges)

    # Step 2: Ensure the graph is a DAG by removing cycles
    result = mwfas2(file_path)
    new_graph = result['final_graph']
    new_weights = {key: value for key, value in init_weights.items() if key not in result['removed_weights']}

    # Step 3: Compute rankings for the vertices using the modified graph
    final_rankings = compute_vertex_rankings(new_graph, new_weights, n)
    print("final ranking=",final_rankings)
    # Step 4: Evaluate upset losses before optimization
    scores = torch.FloatTensor(final_rankings).view(-1, 1)
    adjacency_matrix = graph_to_adjacency_matrix(init_graph, init_weights, n)

    print("Evaluating losses before optimization...")
    naive_loss_before = calculate_upset_loss(adjacency_matrix, scores, style='naive')
    simple_loss_before = calculate_upset_loss(adjacency_matrix, scores, style='simple')
    ratio_loss_before = calculate_upset_loss(adjacency_matrix, scores, style='ratio')
    end_time = time.time()
    elapsed_time = end_time - start_time
    print("Before Optimization:")
    print(f"Naive Loss: {naive_loss_before}")
    print(f"Simple Loss: {simple_loss_before}")
    print(f"Ratio Loss: {ratio_loss_before}")
    print(f"Elapsed Time: {elapsed_time:.4f} seconds")
# Out:
# Processing file: England 2009 2010.txt - Number of nodes: 20, Number of edges: 164
# final ranking= [8, 16, 19, 4, 13, 5, 7, 2, 0, 6, 1, 17, 15, 9, 12, 10, 14, 11, 18, 3]
# Evaluating losses before optimization...
# Before Optimization:
# Naive Loss: 0.18292683362960815
# Simple Loss: 0.7317073345184326
# Ratio Loss: 0.5951723456382751
# Elapsed Time: 0.0410 seconds

# %%
def berger_shor_fas(file_path):
    """
    Implements the Berger-Shor algorithm for finding a feedback arc set (FAS).

    Args:
        file_path (str): Path to the file containing the graph.

    Returns:
        dict: Contains the final DAG, removed edges, and related metrics.
    """
    # Step 1: Read the graph
    edges = read_graph(file_path)
    n = max(max(u, v) for u, v, _, _ in edges) + 1
    graph, weights = initialize_graph(edges)

    # Step 2: Compute the feedback arc set
    feedback_arc_set = []
    removed_weights = {}

    while graph:
        min_node = None
        min_weight = float('inf')

        for node in list(graph.keys()):
            in_edges = [(u, node, eid) for u in graph for v, eid in graph[u] if v == node]
            out_edges = [(node, v, eid) for v, eid in graph[node]]

            in_weight = sum(weights.get(edge, 0) for edge in in_edges)
            out_weight = sum(weights.get(edge, 0) for edge in out_edges)

            total_weight = in_weight + out_weight

#            print(f"Node: {node}, In-Weight: {in_weight}, Out-Weight: {out_weight}, Total Weight: {total_weight}")

            if total_weight < min_weight:
                min_weight = total_weight
                min_node = node

#        print(f"Selected Min Node: {min_node}, Min Weight: {min_weight}")

        if min_node is not None:
            for u, v, eid in [(u, min_node, eid) for u in graph for v, eid in graph[u] if v == min_node]:
                feedback_arc_set.append((u, v, eid))
                removed_weights[(u, v, eid)] = weights.get((u, v, eid), 0)

            graph.pop(min_node, None)

            for u in list(graph.keys()):
                graph[u] = [(v, eid) for v, eid in graph[u] if v != min_node]

        if not graph:  # Ensure termination for edge cases
            break

    # Step 3: Construct the final graph
    final_graph = defaultdict(list)
    for u, adj in initialize_graph(edges)[0].items():
        for v, eid in adj:
            if (u, v, eid) not in feedback_arc_set:
                final_graph[u].append((v, eid))

#    print("Final Feedback Arc Set:", feedback_arc_set)

    # Validate the final graph is a DAG
    if not is_dag(final_graph):
        print("Error: The final graph is not a DAG!")
    else:
        print("The final graph is a DAG.")

    # Print number of edges in the final graph
    final_edge_count = sum(len(adj) for adj in final_graph.values())
    print(f"Number of edges in the final graph: {final_edge_count}")

    return {
        "final_graph": final_graph,
        "removed_edges": feedback_arc_set,
        "removed_weights": removed_weights,
        "total_removed_weight": sum(removed_weights.values()),
    }

def greedy_fas(file_path):
    """
    Implements a greedy algorithm for finding a feedback arc set (FAS).

    Args:
        file_path (str): Path to the file containing the graph.

    Returns:
        dict: Contains the final DAG, removed edges, and related metrics.
    """
    # Step 1: Read the graph
    edges = read_graph(file_path)
    n = max(max(u, v) for u, v, _, _ in edges) + 1
    graph, weights = initialize_graph(edges)

    # Step 2: Compute the feedback arc set
    feedback_arc_set = []
    removed_weights = {}

    while graph:
        max_node = None
        max_difference = float('-inf')

        for node in list(graph.keys()):
            in_edges = [(u, node, eid) for u in graph for v, eid in graph[u] if v == node]
            out_edges = [(node, v, eid) for v, eid in graph[node]]

            in_weight = sum(weights.get(edge, 0) for edge in in_edges)
            out_weight = sum(weights.get(edge, 0) for edge in out_edges)

            difference = out_weight - in_weight

   #         print(f"Node: {node}, In-Weight: {in_weight}, Out-Weight: {out_weight}, Difference: {difference}")

            if difference > max_difference:
                max_difference = difference
                max_node = node

   #     print(f"Selected Max Node: {max_node}, Max Difference: {max_difference}")

        if max_node is not None:
            for u, v, eid in [(u, max_node, eid) for u in graph for v, eid in graph[u] if v == max_node]:
                feedback_arc_set.append((u, v, eid))
                removed_weights[(u, v, eid)] = weights.get((u, v, eid), 0)

            graph.pop(max_node, None)

            for u in list(graph.keys()):
                graph[u] = [(v, eid) for v, eid in graph[u] if v != max_node]

        if not graph:  # Ensure termination for edge cases
            break

    # Step 3: Construct the final graph
    final_graph = defaultdict(list)
    for u, adj in initialize_graph(edges)[0].items():
        for v, eid in adj:
            if (u, v, eid) not in feedback_arc_set:
                final_graph[u].append((v, eid))

#    print("Final Feedback Arc Set:", feedback_arc_set)

    # Validate the final graph is a DAG
    if not is_dag(final_graph):
        print("Error: The final graph is not a DAG!")
    else:
        print("The final graph is a DAG.")

    # Print number of edges in the final graph
    final_edge_count = sum(len(adj) for adj in final_graph.values())
    print(f"Number of edges in the final graph: {final_edge_count}")

    return {
        "final_graph": final_graph,
        "removed_edges": feedback_arc_set,
        "removed_weights": removed_weights,
        "total_removed_weight": sum(removed_weights.values()),
    }

def is_dag(graph):
    """
    Checks if a graph is a Directed Acyclic Graph (DAG).

    Args:
        graph (dict): The graph represented as an adjacency list.

    Returns:
        bool: True if the graph is a DAG, False otherwise.
    """
    visited = set()
    stack = set()

    def dfs(node):
        if node in stack:  # Cycle detected
            return False
        if node in visited:
            return True
        visited.add(node)
        stack.add(node)
        for neighbor, _ in graph.get(node, []):
            if not dfs(neighbor):
                return False
        stack.remove(node)
        return True

    for node in graph:
        if not dfs(node):
            return False
    return True

# %%
results = []



# Iterate through each input file
for file_path in file_paths:
    start_time = time.time()

    # Step 1: Read the graph and initialize structures
    edges = read_graph(file_path)
    n = max(max(u, v) for u, v, _, _ in edges) + 1
    print(f"Processing file: {file_path} - Number of nodes: {n}, Number of edges: {len(edges)}")

    init_graph, init_weights = initialize_graph(edges)

    # Step 2: Ensure the graph is a DAG by removing cycles
    result = greedy_fas(file_path)
    new_graph = result['final_graph']
    new_weights = {key: value for key, value in init_weights.items() if key not in result['removed_weights']}

    # Step 3: Compute rankings for the vertices using the modified graph
    final_rankings = compute_vertex_rankings(new_graph, new_weights, n)
    print("final ranking=",final_rankings)
    # Step 4: Evaluate upset losses before optimization
    scores = torch.FloatTensor(final_rankings).view(-1, 1)
    adjacency_matrix = graph_to_adjacency_matrix(init_graph, init_weights, n)

    print("Evaluating losses before optimization...")
    naive_loss_before = calculate_upset_loss(adjacency_matrix, scores, style='naive')
    simple_loss_before = calculate_upset_loss(adjacency_matrix, scores, style='simple')
    ratio_loss_before = calculate_upset_loss(adjacency_matrix, scores, style='ratio')
    end_time = time.time()
    elapsed_time = end_time - start_time
    print("Before Optimization:")
    print(f"Naive Loss: {naive_loss_before}")
    print(f"Simple Loss: {simple_loss_before}")
    print(f"Ratio Loss: {ratio_loss_before}")
    print(f"Elapsed Time: {elapsed_time:.4f} seconds")
# Out:
# Processing file: England 2009 2010.txt - Number of nodes: 20, Number of edges: 164
# The final graph is a DAG.
# Number of edges in the final graph: 137
# final ranking= [11, 16, 19, 6, 14, 5, 4, 1, 0, 7, 3, 17, 13, 10, 12, 9, 15, 8, 18, 2]
# Evaluating losses before optimization...
# Before Optimization:
# Naive Loss: 0.1463414579629898
# Simple Loss: 0.5853658318519592
# Ratio Loss: 0.5942490100860596
# Elapsed Time: 0.0548 seconds

# %%
results = []



# Iterate through each input file
for file_path in file_paths:
    start_time = time.time()

    # Step 1: Read the graph and initialize structures
    edges = read_graph(file_path)
    n = max(max(u, v) for u, v, _, _ in edges) + 1
    print(f"Processing file: {file_path} - Number of nodes: {n}, Number of edges: {len(edges)}")

    init_graph, init_weights = initialize_graph(edges)

    # Step 2: Ensure the graph is a DAG by removing cycles
    result = berger_shor_fas(file_path)
    new_graph = result['final_graph']
    new_weights = {key: value for key, value in init_weights.items() if key not in result['removed_weights']}

    # Step 3: Compute rankings for the vertices using the modified graph
    final_rankings = compute_vertex_rankings(new_graph, new_weights, n)
    print("final ranking=",final_rankings)
    # Step 4: Evaluate upset losses before optimization
    scores = torch.FloatTensor(final_rankings).view(-1, 1)
    adjacency_matrix = graph_to_adjacency_matrix(init_graph, init_weights, n)

    print("Evaluating losses before optimization...")
    naive_loss_before = calculate_upset_loss(adjacency_matrix, scores, style='naive')
    simple_loss_before = calculate_upset_loss(adjacency_matrix, scores, style='simple')
    ratio_loss_before = calculate_upset_loss(adjacency_matrix, scores, style='ratio')
    end_time = time.time()
    elapsed_time = end_time - start_time
    print("Before Optimization:")
    print(f"Naive Loss: {naive_loss_before}")
    print(f"Simple Loss: {simple_loss_before}")
    print(f"Ratio Loss: {ratio_loss_before}")
    print(f"Elapsed Time: {elapsed_time:.4f} seconds")
# Out:
# Processing file: England 2009 2010.txt - Number of nodes: 20, Number of edges: 164
# The final graph is a DAG.
# Number of edges in the final graph: 73
# final ranking= [10, 15, 9, 5, 19, 14, 18, 1, 12, 6, 3, 8, 11, 7, 17, 16, 0, 13, 4, 2]
# Evaluating losses before optimization...
# Before Optimization:
# Naive Loss: 0.39024388790130615
# Simple Loss: 1.5609755516052246
# Ratio Loss: 1.1017802953720093
# Elapsed Time: 0.0336 seconds
